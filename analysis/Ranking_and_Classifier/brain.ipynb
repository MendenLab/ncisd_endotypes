# %%
import script_classifier

# %%
m = script_classifier.Module()

# %%
m.create_gene_scores()
# Out:
#   0%|                                                    | 0/20 [00:00<?, ?it/s]Process SpawnProcess-2:
# Traceback (most recent call last):
#   File "/opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/multiprocessing/process.py", line 320, in _bootstrap
#     self.run()
#     ~~~~~~~~^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/process.py", line 242, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/multiprocessing/queues.py", line 120, in get
#     return _ForkingPickler.loads(res)
# ...
